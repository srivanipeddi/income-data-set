# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
income=pd.read_csv('RBI DATA states_wise_population_Income.csv')

# %%
income
# Out:
#        States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  \
# 0   Andaman and Nicobar Islands        25047        89642       81.30
# 1                Andhra Pradesh        17195        64773       60.47
# 2             Arunachal Pradesh        15260        71366       54.34
# 3                         Assam        12803        36320       63.25
# 4                         Bihar         6415        22582       47.00
# 5                    Chandigarh        49771       136883       81.94
# 6                  Chhattisgarh        10744        48366       64.66
# 7                         Delhi        40678       161446       57.63
# 8                           Goa        43735       211570       78.18
# 9                       Gujarat        18392        85979       81.67
# 10                      Haryana        25583       106320       82.01
# 11             Himachal Pradesh        22795        75185       69.14
# ...

# %%
income.head()
# Out:
#       States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  \
# 0  Andaman and Nicobar Islands        25047        89642       81.30
# 1               Andhra Pradesh        17195        64773       60.47
# 2            Arunachal Pradesh        15260        71366       54.34
# 3                        Assam        12803        36320       63.25
# 4                        Bihar         6415        22582       47.00
#
#    2011- LIT  2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  \
# 0      86.63         356        381              846              876
# 1      67.02       76210      84581              978              993
# 2      65.39        1098       1384              893              938
# 3      72.19       26656      31206              935              958
# 4      61.80       82999     104099              919              918
#
#    2001 -UNEMP  2011 -UNEMP  2001 -Poverty  2011 -Poverty
# 0           34           54          20.99           1.00
# ...

# %%
income.tail()
# Out:
#    States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  2011- LIT  \
# 27               Tamil Nadu        20972        89050       69.65      75.84
# 28                  Tripura        15983        50859       68.81      81.42
# 29            Uttar Pradesh         9828        30021       73.45      80.09
# 30              Uttarakhand        15285        85372       73.19      87.22
# 31              West Bengal        16583        53383       56.27      67.68
#
#     2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  2001 -UNEMP  \
# 27       62406      72147              987              996           20
# 28        3199       3674              948              960           12
# 29      166198     199812              898              912            8
# 30        8489      10086              962              963           22
# 31       80176      91276              934              950           28
#
#     2011 -UNEMP  2001 -Poverty  2011 -Poverty
# ...

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   States_Union Territories  32 non-null     object
#  1   2000-01-INC               32 non-null     int64
#  2   2011-12-INC               32 non-null     int64
#  3   2001 - LIT                32 non-null     float64
#  4   2011- LIT                 32 non-null     float64
#  5   2001 - POP                32 non-null     int64
#  6   2011- POP                 32 non-null     int64
#  7   2001 -SEX_Ratio           32 non-null     int64
#  8   2011 -SEX_Ratio           32 non-null     int64
#  9   2001 -UNEMP               32 non-null     int64
#  10  2011 -UNEMP               32 non-null     int64
#  11  2001 -Poverty             32 non-null     float64
#  12  2011 -Poverty             32 non-null     float64
# dtypes: float64(4), int64(8), object(1)
# ...

# %%
income.isnull().sum()
# Out:
# States_Union Territories    0
# 2000-01-INC                 0
# 2011-12-INC                 0
# 2001 - LIT                  0
# 2011- LIT                   0
# 2001 - POP                  0
# 2011- POP                   0
# 2001 -SEX_Ratio             0
# 2011 -SEX_Ratio             0
# 2001 -UNEMP                 0
# 2011 -UNEMP                 0
# 2001 -Poverty               0
# 2011 -Poverty               0
# dtype: int64

# %%
income[income.duplicated()]
# Out:
# Empty DataFrame
# Columns: [States_Union Territories, 2000-01-INC, 2011-12-INC, 2001 - LIT, 2011- LIT, 2001 - POP, 2011- POP, 2001 -SEX_Ratio, 2011 -SEX_Ratio, 2001 -UNEMP, 2011 -UNEMP, 2001 -Poverty, 2011 -Poverty]
# Index: []

# %%
income.drop_duplicates(inplace=True)

# %%
income.nunique()
# Out:
# States_Union Territories    32
# 2000-01-INC                 32
# 2011-12-INC                 32
# 2001 - LIT                  32
# 2011- LIT                   32
# 2001 - POP                  32
# 2011- POP                   32
# 2001 -SEX_Ratio             28
# 2011 -SEX_Ratio             30
# 2001 -UNEMP                 21
# 2011 -UNEMP                 25
# 2001 -Poverty               32
# 2011 -Poverty               32
# dtype: int64

# %%
income['States_Union Territories'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0     Andaman and Nicobar Islands
# 1                  Andhra Pradesh
# 2               Arunachal Pradesh
# 3                           Assam
# 4                           Bihar
# 5                      Chandigarh
# 6                    Chhattisgarh
# 7                           Delhi
# 8                             Goa
# 9                         Gujarat
# 10                        Haryana
# 11               Himachal Pradesh
# 12              Jammu and Kashmir
# 13                      Jharkhand
# 14                      Karnataka
# 15                         Kerala
# 16                 Madhya Pradesh
# 17                    Maharashtra
# 18                        Manipur
# 19                      Meghalaya
# 20                        Mizoram
# 21                       Nagaland
# 22                         Odisha
# 23                     Puducherry
# 24                         Punjab
# 25                      Rajasthan
# ...

# %%
income.nlargest(5,'2000-01-INC')
# Out:
#    States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  2011- LIT  \
# 5                Chandigarh        49771       136883       81.94      86.05
# 8                       Goa        43735       211570       78.18      87.10
# 7                     Delhi        40678       161446       57.63      76.24
# 23               Puducherry        35994       103149       88.80      91.33
# 24                   Punjab        27881        76895       66.59      79.60
#
#     2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  2001 -UNEMP  \
# 5          901       1055              777              818            7
# 8         1348       1459              961              973           93
# 7        13851      16788              821              868           47
# 23         974       1248             1001             1037           40
# 24       24359      27743              876              895           18
#
#     2011 -UNEMP  2001 -Poverty  2011 -Poverty
# ...

# %%
income.nsmallest(5,'2000-01-INC')
# Out:
#    States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  2011- LIT  \
# 4                     Bihar         6415        22582       47.00      61.80
# 29            Uttar Pradesh         9828        30021       73.45      80.09
# 13                Jharkhand        10345        36554       76.48      82.80
# 22                   Odisha        10453        43463       62.56      74.43
# 6              Chhattisgarh        10744        48366       64.66      70.28
#
#     2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  2001 -UNEMP  \
# 4        82999     104099              919              918           18
# 29      166198     199812              898              912            8
# 13       26946      32988              941              948           20
# 22       36805      41974              972              979           19
# 6        20834      25545              989              991           16
#
#     2011 -UNEMP  2001 -Poverty  2011 -Poverty
# ...

# %%
income.nlargest(5,'2011-12-INC')
# Out:
#    States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  2011- LIT  \
# 8                       Goa        43735       211570       78.18      87.10
# 7                     Delhi        40678       161446       57.63      76.24
# 5                Chandigarh        49771       136883       81.94      86.05
# 26                   Sikkim        16077       130127       81.24      85.85
# 10                  Haryana        25583       106320       82.01      88.70
#
#     2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  2001 -UNEMP  \
# 8         1348       1459              961              973           93
# 7        13851      16788              821              868           47
# 5          901       1055              777              818            7
# 26         541        611              875              890           28
# 10       21145      25351              861              879            8
#
#     2011 -UNEMP  2001 -Poverty  2011 -Poverty
# ...

# %%
income.nsmallest(5,'2011-12-INC')
# Out:
#    States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  2011- LIT  \
# 4                     Bihar         6415        22582       47.00      61.80
# 29            Uttar Pradesh         9828        30021       73.45      80.09
# 18                  Manipur        12369        33695       86.66      91.85
# 3                     Assam        12803        36320       63.25      72.19
# 13                Jharkhand        10345        36554       76.48      82.80
#
#     2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  2001 -UNEMP  \
# 4        82999     104099              919              918           18
# 29      166198     199812              898              912            8
# 18        2294       2856              978              992           19
# 3        26656      31206              935              958           39
# 13       26946      32988              941              948           20
#
#     2011 -UNEMP  2001 -Poverty  2011 -Poverty
# ...

# %%
plt.figure(figsize=(22,5))
income.boxplot()
# Out:
# <AxesSubplot:>

# %%
income1=income[income['2011-12-INC']<161000]
income1.boxplot('2011-12-INC')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
sns.heatmap(income.corr(),cmap='rainbow',annot=True)
# Out:
# <AxesSubplot:>

# %%
i1=income.pivot_table(index='States_Union Territories',columns='2011-12-INC',values='2000-01-INC')
sns.heatmap(i1)
# Out:
# <AxesSubplot:xlabel='2011-12-INC', ylabel='States_Union Territories'>

# %%
i2=income.pivot_table(index='States_Union Territories',columns='2000-01-INC',values='2011-12-INC')
sns.heatmap(i2)
# Out:
# <AxesSubplot:xlabel='2000-01-INC', ylabel='States_Union Territories'>

# %%
i3=income.pivot_table(index='States_Union Territories',columns='2001 -Poverty',values='2011 -Poverty')
sns.heatmap(i3)
# Out:
# <AxesSubplot:xlabel='2001 -Poverty', ylabel='States_Union Territories'>

# %%
i4=income.pivot_table(index='States_Union Territories',columns='2011 -Poverty',values='2001 -Poverty')
sns.heatmap(i4)
# Out:
# <AxesSubplot:xlabel='2011 -Poverty', ylabel='States_Union Territories'>

# %%
income
# Out:
#        States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  \
# 0   Andaman and Nicobar Islands        25047        89642       81.30
# 1                Andhra Pradesh        17195        64773       60.47
# 2             Arunachal Pradesh        15260        71366       54.34
# 3                         Assam        12803        36320       63.25
# 4                         Bihar         6415        22582       47.00
# 5                    Chandigarh        49771       136883       81.94
# 6                  Chhattisgarh        10744        48366       64.66
# 7                         Delhi        40678       161446       57.63
# 8                           Goa        43735       211570       78.18
# 9                       Gujarat        18392        85979       81.67
# 10                      Haryana        25583       106320       82.01
# 11             Himachal Pradesh        22795        75185       69.14
# ...
